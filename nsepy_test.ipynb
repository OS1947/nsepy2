# %%
from nsepy import *
from datetime import date
#import matplotlib as plt

# %%
data = get_history(symbol="SBIN", start=date(2010,1,1), end=date(2021,12,31))

# %%
data.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last    Close  \
# Date
# 2010-01-04   SBIN     EQ     2269.00  2275.0  2300.0  2275.0  2294.0  2291.20
# 2010-01-05   SBIN     EQ     2291.20  2308.0  2310.0  2280.1  2294.0  2292.05
# 2010-01-06   SBIN     EQ     2292.05  2297.0  2315.0  2285.0  2300.0  2305.80
# 2010-01-07   SBIN     EQ     2305.80  2306.0  2310.0  2281.1  2292.0  2292.90
# 2010-01-08   SBIN     EQ     2292.90  2294.0  2303.9  2280.1  2287.7  2286.05
#
#                VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2010-01-04  2291.26  1103147  2.527599e+14     NaN              313202
# 2010-01-05  2292.78  1161374  2.662776e+14     NaN              522468
# 2010-01-06  2301.72  1452793  3.343920e+14     NaN              577097
# 2010-01-07  2291.86   857651  1.965618e+14     NaN              333190
# 2010-01-08  2289.08  1045382  2.392961e+14     NaN              535343
#
#             %Deliverble
# Date
# ...

# %%
data.to_csv("SBIN_2010_to_2021.csv")

# %% [markdown]
# Old data

# %%
data_2001 = get_history(symbol="SBIN", start=date(2001,1,1), end=date(2001,12,31))

# %%
data_2022_Nov = get_history(symbol="SBIN", start=date(2022,10,1), end=date(2022,11,11))

# %%
data_2022_Nov
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2022-10-03   SBIN     EQ      530.60  527.60  531.65  518.50  518.95  519.75
# 2022-10-04   SBIN     EQ      519.75  533.00  535.80  527.80  532.95  532.70
# 2022-10-06   SBIN     EQ      532.70  534.60  541.80  534.60  537.35  537.30
# 2022-10-07   SBIN     EQ      537.30  535.50  535.60  526.55  531.00  530.20
# 2022-10-10   SBIN     EQ      530.20  525.70  533.90  522.20  531.40  530.75
# 2022-10-11   SBIN     EQ      530.75  530.75  533.70  525.50  527.00  527.40
# 2022-10-12   SBIN     EQ      527.40  530.00  535.00  526.00  535.00  533.80
# 2022-10-13   SBIN     EQ      533.80  533.00  533.80  520.20  521.90  521.45
# 2022-10-14   SBIN     EQ      521.45  530.20  534.85  526.00  527.80  527.20
# 2022-10-17   SBIN     EQ      527.20  526.40  544.70  524.20  543.20  543.65
# 2022-10-18   SBIN     EQ      543.65  547.10  563.50  546.75  562.40  562.45
# ...

# %%
data_2001.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2001-01-01   SBIN     EQ      192.65  193.55  197.80  191.10  195.65  195.00
# 2001-01-02   SBIN     EQ      195.00  197.60  209.00  195.15  209.00  205.80
# 2001-01-03   SBIN     EQ      205.80  206.00  220.45  205.10  216.50  217.30
# 2001-01-04   SBIN     EQ      217.30  218.40  221.00  209.25  213.70  212.65
# 2001-01-05   SBIN     EQ      212.65  212.70  218.40  210.65  214.00  214.95
#
#               VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2001-01-01  195.28  1060252  2.070511e+13     NaN                 NaN
# 2001-01-02  202.15  2016036  4.075442e+13     NaN                 NaN
# 2001-01-03  214.19  5582579  1.195745e+14     NaN                 NaN
# 2001-01-04  214.36  2779351  5.957702e+13     NaN                 NaN
# 2001-01-05  215.22  2795495  6.016447e+13     NaN                 NaN
#
#             %Deliverble
# Date
# 2001-01-01          NaN
# ...

# %% [markdown]
# List of securities / scrips traded at NSE

# %%
from nsepy.symbols import *
scrip_list = get_symbol_list()
len(scrip_list)
# Out:
# 1836

# %% [markdown]
# Index constituents

# %%
nifty50 = get_index_constituents_list("nifty")
nifty50
# Out:
#                                     Company Name                  Industry  \
# 0                                       ACC Ltd.  CEMENT & CEMENT PRODUCTS
# 1     Adani Ports and Special Economic Zone Ltd.                  SERVICES
# 2                            Ambuja Cements Ltd.  CEMENT & CEMENT PRODUCTS
# 3                              Asian Paints Ltd.            CONSUMER GOODS
# 4                                 Axis Bank Ltd.        FINANCIAL SERVICES
# 5                                Bajaj Auto Ltd.                AUTOMOBILE
# 6                                 Bank of Baroda        FINANCIAL SERVICES
# 7                  Bharat Heavy Electricals Ltd.  INDUSTRIAL MANUFACTURING
# 8              Bharat Petroleum Corporation Ltd.                    ENERGY
# 9                             Bharti Airtel Ltd.                   TELECOM
# 10                                    Bosch Ltd.                AUTOMOBILE
# ...

# %% [markdown]
# Indices and their EOD data, date wise

# %%
from nsepy.history import *
dt = date(2022,11,11)
indices_eod = get_indices_price_list(dt)
indices_eod
# Out:
#                                           NAME   TIMESTAMP      OPEN  \
# 0                                     Nifty 50  11-11-2022  18272.35
# 1                                Nifty Next 50  11-11-2022   43224.2
# 2                                    Nifty 100  11-11-2022  18505.95
# 3                                    Nifty 200  11-11-2022    9675.5
# 4                                    Nifty 500  11-11-2022   15633.5
# ..                                         ...         ...       ...
# 99                 Nifty Composite G-sec Index  11-11-2022   2380.95
# 100                Nifty 10 yr Benchmark G-Sec  11-11-2022   2044.23
# 101  Nifty 10 yr Benchmark G-Sec (Clean Price)  11-11-2022    863.63
# 102                        Nifty 1D Rate Index  11-11-2022         -
# 103                                Nifty50 USD  11-11-2022         -
#
#          HIGH       LOW     CLOSE  CHANGE CHANGEPCT   TOTTRDQTY TOTTRDVAL  \
# ...
